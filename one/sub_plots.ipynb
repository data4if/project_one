# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)
y=np.sin(x)

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'b')

# %%
# la salida de los arrays se puede usar tuplas axes cambia ax1 y ax2 entre parentesis
fig, axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y,'r')
axes[1].plot(y,x,'b')

# %%
fig, axes = plt.subplots(nrows=2,ncols=4)
y=np.cos(x)
axes[0,0].plot(x,y,'r')
axes[0,1].plot(x,np.sin(x),'b')
axes[1,0].plot(x,np.sin(x),'r')
axes[1,1].plot(x,np.tan(x),'y')
fig.tight_layout()
