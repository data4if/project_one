# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
# (Numero de filas, Numero de columnas)
plt.subplot(1,2,1)
plt.hist(x,y)
plt.subplot(1,2,2)
plt.plot(x,y)
plt.plot(y,x)
