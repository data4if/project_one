# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Opciones de configuracion para modificar las graficas generadas con plot
#
# ![ Opciones de configuracion de plot ](/Users/data4if/Desktop/Data-Science/project_one/one/opciones_pyplot.png)

# %%
# Rango de 0 hasta 5, Numero de valores 11 / np.linspace
x=np.linspace(0,5,11)
y=x**2
# 
plt.plot(x,y,'bD-')
plt.show()

# %%
plt.hist(x)
plt.show()
