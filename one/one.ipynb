# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Opciones de configuracion para modificar las graficas generadas con plot
#
# <img src="/Users/data4if/Desktop/Data-Science/project_one/one/opciones_pyplot.png" alt="Texto Alternativo" width="500" height="1000">
#
# Nota: si no logras ver las visualizaciones de las imagenes en la carpeta de one estaran alojadas todas para que puedas editar las rutas absolutas

# %%
# Rango de 0 hasta 5, Numero de valores 11 / np.linspace
x=np.linspace(0,5,11)
y=x**2
# 
plt.plot(x,y,'bD-')
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
plt.pie(y)
plt.show()

# %%
plt.scatter(x,y)  #correlacion entre la variable x e y
plt.show()

# %%
plt.boxplot(x)
plt.show()
