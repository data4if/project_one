# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)
y=np.sin(x)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(5,5))
axes[0].plot(x,y, label='sin(x)')
axes[0].set_title('Relacion X - Y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].legend()

axes[1].plot(y,x)
axes[1].set_title('Relacion Y - X')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('X')
# Out:
# Text(0, 0.5, 'X')

# %%
plt.style.use('dark_background')
# Tipos de estilo disponible
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
x=np.linspace(0,5,11)
y=np.sin(x)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y)
axes[0].set_title('Relacion X -y')
axes[1].plot(y,x)
axes[1].set_title('Relacion X -y')
# Out:
# Text(0.5, 1.0, 'Relacion X -y')

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,x+1,'r--')
ax.plot(x,x+2,'b-')
ax.plot(x,x+3,'g.-')
ax.plot(x,x+4,'yo:')

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,x+1, color='green', alpha=0.8, linewidth=7, linestyle='--', marker='D', markersize=11, markerfacecolor='r')
ax.plot(x,x+2,'-', color='#66FF66', linewidth=9, linestyle='dashed')
ax.plot(x,x+3,'g.-')
ax.plot(x,x+4,'yo:')
# Out:
# /var/folders/py/v072kc5d653b5l3crrllpr100000gn/T/ipykernel_5748/4037319719.py:3: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(x,x+2,'-', color='#66FF66', linewidth=9, linestyle='dashed')
